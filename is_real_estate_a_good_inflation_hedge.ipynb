# %%
import pandas as pd
from main_real_estate_price_index import get_price_change
from cpi import get_cpi
import plotly.express as px
from IPython.display import display, Markdown
display(Markdown("# Hello World!"))
# Out:
# # Hello World!

# %%
cpi_df = get_cpi(look_back_window=12)
real_estate_df = get_price_change(look_back_window=12)
df = cpi_df.join(real_estate_df)
df = df.dropna(how='any', axis=0)

# %%
# general line chart
df_for_fig = df.rename(columns={'inflation': 'YOY inflation rate', 'price_change': 'yearly change (%) in real estate prices'}).reset_index()
df_for_fig = pd.melt(df_for_fig,  id_vars=['dt'], value_vars=['YOY inflation rate', 'yearly change (%) in real estate prices'])
fig = px.line(df_for_fig, y="value", x='dt', color='variable')
fig.update_layout(xaxis_title='Date', yaxis_title='Yearly change (%)', )
fig.update_layout(title_text="Inflation and real estate prices in israel", title_x=0.5, titlefont=dict(size=30))
fig.update_layout(yaxis=dict(tickfont=dict(size=15),
                             tickvals=[x * 2.5 for x in range(-4, 10)],
                             ticktext=[str(round(x * 2.5, 1)) + '%' for x in range(-4, 10)],
                             titlefont=dict(size=25)))
fig.update_layout(xaxis=dict(tickfont=dict(size=20), titlefont=dict(size=25)))
fig.update_layout(legend=dict(title="Index"))
fig.show()
# Out:
# <div>                            <div id="3f01b44a-c134-4447-bd89-27a151b32062" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f01b44a-c134-4447-bd89-27a151b32062")) {                    Plotly.newPlot(                        "3f01b44a-c134-4447-bd89-27a151b32062",                        [{"hovertemplate": "variable=YOY inflation rate<br>dt=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "YOY inflation rate", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "YOY inflation rate", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["1995-01-01T00:00:00", "1995-02-01T00:00:00", "1995-03-01T00:00:00", "1995-04-01T00:00:00", "1995-05-01T00:00:00", "1995-06-01T00:00:00", "1995-07-01T00:00:00", "1995-08-01T00:00:00", "1995-09-01T00:00:00", "1995-10-01T00:00:00", "1995-11-01T00:00:00", "1995-12-01T00:00:00", "1996-01-01T00:00:00", "1996-02-01T00:00:00", "1996-03-01T00:00:00", "1996-04-01T00:00:00", "1996-05-01T00:00:00", "1996-06-01T00:00:00", "1996-07-01T00:00:00", "1996-08-01T00:00:00", "1996-09-01T00:00:00", "1996-10-01T00:00:00", "1996-11-01T00:00:00", "1996-12-01T00:00:00", "1997-01-01T00:00:00", "1997-02-01T00:00:00", "1997-03-01T00:00:00", "1997-04-01T00:00:00", "1997-05-01T00:00:00", "1997-06-01T00:00:00", "1997-07-01T00:00:00", "1997-08-01T00:00:00", "1997-09-01T00:00:00", "1997-10-01T00:00:00", "1997-11-01T00:00:00", "1997-12-01T00:00:00", "1998-01-01T00:00:00", "1998-02-01T00:00:00", "1998-03-01T00:00:00", "1998-04-01T00:00:00", "1998-05-01T00:00:00", "1998-06-01T00:00:00", "1998-07-01T00:00:00", "1998-08-01T00:00:00", "1998-09-01T00:00:00", "1998-10-01T00:00:00", "1998-11-01T00:00:00", "1998-12-01T00:00:00", "1999-01-01T00:00:00", "1999-02-01T00:00:00", "1999-03-01T00:00:00", "1999-04-01T00:00:00", "1999-05-01T00:00:00", "1999-06-01T00:00:00", "1999-07-01T00:00:00", "1999-08-01T00:00:00", "1999-09-01T00:00:00", "1999-10-01T00:00:00", "1999-11-01T00:00:00", "1999-12-01T00:00:00", "2000-01-01T00:00:00", "2000-02-01T00:00:00", "2000-03-01T00:00:00", "2000-04-01T00:00:00", "2000-05-01T00:00:00", "2000-06-01T00:00:00", "2000-07-01T00:00:00", "2000-08-01T00:00:00", "2000-09-01T00:00:00", "2000-10-01T00:00:00", "2000-11-01T00:00:00", "2000-12-01T00:00:00", "2001-01-01T00:00:00", "2001-02-01T00:00:00", "2001-03-01T00:00:00", "2001-04-01T00:00:00", "2001-05-01T00:00:00", "2001-06-01T00:00:00", "2001-07-01T00:00:00", "2001-08-01T00:00:00", "2001-09-01T00:00:00", "2001-10-01T00:00:00", "2001-11-01T00:00:00", "2001-12-01T00:00:00", "2002-01-01T00:00:00", "2002-02-01T00:00:00", "2002-03-01T00:00:00", "2002-04-01T00:00:00", "2002-05-01T00:00:00", "2002-06-01T00:00:00", "2002-07-01T00:00:00", "2002-08-01T00:00:00", "2002-09-01T00:00:00", "2002-10-01T00:00:00", "2002-11-01T00:00:00", "2002-12-01T00:00:00", "2003-01-01T00:00:00", "2003-02-01T00:00:00", "2003-03-01T00:00:00", "2003-04-01T00:00:00", "2003-05-01T00:00:00", "2003-06-01T00:00:00", "2003-07-01T00:00:00", "2003-08-01T00:00:00", "2003-09-01T00:00:00", "2003-10-01T00:00:00", "2003-11-01T00:00:00", "2003-12-01T00:00:00", "2004-01-01T00:00:00", "2004-02-01T00:00:00", "2004-03-01T00:00:00", "2004-04-01T00:00:00", "2004-05-01T00:00:00", "2004-06-01T00:00:00", "2004-07-01T00:00:00", "2004-08-01T00:00:00", "2004-09-01T00:00:00", "2004-10-01T00:00:00", "2004-11-01T00:00:00", "2004-12-01T00:00:00", "2005-01-01T00:00:00", "2005-02-01T00:00:00", "2005-03-01T00:00:00", "2005-04-01T00:00:00", "2005-05-01T00:00:00", "2005-06-01T00:00:00", "2005-07-01T00:00:00", "2005-08-01T00:00:00", "2005-09-01T00:00:00", "2005-10-01T00:00:00", "2005-11-01T00:00:00", "2005-12-01T00:00:00", "2006-01-01T00:00:00", "2006-02-01T00:00:00", "2006-03-01T00:00:00", "2006-04-01T00:00:00", "2006-05-01T00:00:00", "2006-06-01T00:00:00", "2006-07-0 ...

# %%
correlation = round(df['inflation'].corr(df['price_change']), 3)
display(Markdown((f"#### We can see a positive correlation between real estate prices and inflation. The correlation found is: {correlation}. In other words, for every 1% change in real estate prices, we\"ll expect to see {correlation}% change in the inflation.")))
# Out:
# #### We can see a positive correlation between real estate prices and inflation. The correlation found is: 0.572. In other words, for every 1% change in real estate prices, we"ll expect to see 0.572% change in the inflation.

# %%
# corr in high\low inflation environment
print("By looking at the chart, we can see that before 2008 the correlation was much higher than after. As a result, I decided to calculated them separately.")
df_before_may_2008 = df.loc[df.index < "2005-05"]
correlation_beofre_may_2008 = round(df_before_may_2008['inflation'].corr(df_before_may_2008['price_change']), 3)
df_after_may_2008 = df.loc[df.index > "2005-05"]
correlation_after_may_2008 = round(df_after_may_2008['inflation'].corr(df_after_may_2008['price_change']), 3)
df_for_fig = pd.DataFrame({'correlation between CPI and real estate prices': [correlation_beofre_may_2008, correlation_after_may_2008],
                   'time':['before May 2008', 'after May 2008']})
fig = px.bar(df_for_fig, y="time", x='correlation between CPI and real estate prices', color="time",
             title="correlation between CPI and real estate prices before and after May 2008",
             text="correlation between CPI and real estate prices", orientation='h')
fig.update_layout(yaxis={'visible': True, 'showticklabels': True, 'title':""})
fig.update_layout(title_x=0.5, titlefont=dict(size=20))
fig.show()
# Out:
# By looking at the chart, we can see that before 2008 the correlation was much higher than after. As a result, I decided to calculated them separately.
# <div>                            <div id="91219bb9-de9a-472c-810c-48567fbca5f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91219bb9-de9a-472c-810c-48567fbca5f5")) {                    Plotly.newPlot(                        "91219bb9-de9a-472c-810c-48567fbca5f5",                        [{"alignmentgroup": "True", "hovertemplate": "time=%{y}<br>correlation between CPI and real estate prices=%{text}<extra></extra>", "legendgroup": "before May 2008", "marker": {"color": "#636efa"}, "name": "before May 2008", "offsetgroup": "before May 2008", "orientation": "h", "showlegend": true, "text": [0.912], "textposition": "auto", "type": "bar", "x": [0.912], "xaxis": "x", "y": ["before May 2008"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "time=%{y}<br>correlation between CPI and real estate prices=%{text}<extra></extra>", "legendgroup": "after May 2008", "marker": {"color": "#EF553B"}, "name": "after May 2008", "offsetgroup": "after May 2008", "orientation": "h", "showlegend": true, "text": [0.491], "textposition": "auto", "type": "bar", "x": [0.491], "xaxis": "x", "y": ["after May 2008"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "time"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale" ...

# %% [markdown]
# from this comparison I can assume that in high inflation environment real estate prices tend to move with inflation.
# another major factor that can help us understand the issue is the interest rate, but the the purpose of this analysis is to investigate whether real estate is a good inflation hedge or not.

# %%
# holding value
hold_value_months = len(df.loc[df['price_change'] > df['inflation']]) * 100
hold_value_percentage = round((hold_value_months/len(df)), 3)
print(f"The yearly change in real estate price was higher than the yearly inflation rate in {hold_value_percentage}% of the months explored.")
print()
print("Holding real estate might help avoiding the decrease in value of your money, but it will not protect you from our neighbors, and the lack of peace in the middle east.")
print("Therefore, I would ask the same question again, excluding the second intifada (september 2000 to february 2005), all other war periods in the time we are looking at where shorter than 2 month, and affected mainly the south/north of the country.")
print()
df_no_war = df.loc[(df.index < "2000-09") | (df.index > "2005-02")]
no_war_hold_value_months = len(df_no_war.loc[df_no_war['price_change'] > df_no_war['inflation']]) * 100
no_war_hold_value_percentage = round((no_war_hold_value_months/len(df_no_war)), 3)
print(f"When we exclude the war periods, in {no_war_hold_value_percentage}% of the months the yearly change in real estate prices was higher than inflation.")
print(f"This means that real estate value in average went up in real term (inflation adjusted) {no_war_hold_value_percentage}% of the months")
# Out:
# yearly real estate price change was higher than yearly inflation rate in 61.728% of the months explored.
#
# holding real estate might help to avoid the decrease in value of your money, but it will not protect you from our neighbors, and the lack of peace in the middle east.
# therefore I would ask the same question again, excluding the second intifada (september 2000 to february 2005), all other war periods in the time we are looking at where shorter than 2 month, and affected mainly the south/north of the country.
#
# when we exclude the war periods, in 70.37% of the months the yearly change in real estate prices was higher than inflation.
# which means that real estate value in average went up in real term (inflation adjusted) 70.37% of the months

# %%
df_for_fig = pd.DataFrame({'Hold value percentage': [hold_value_percentage, no_war_hold_value_percentage],
                   'time':['All times', 'No war time']})
fig = px.bar(df_for_fig, y="time", x='Hold value percentage', color="time",
             title="Real estate holding value percentage exculding vs not excluding war times",
             text="Hold value percentage", orientation='h')
fig.update_layout(yaxis={'visible': True, 'showticklabels': True, 'title':""})
fig.update_layout(title_x=0.5, titlefont=dict(size=20))
fig.show()
# Out:
# <div>                            <div id="f35a0724-e81e-4e5d-ae66-607fc29025a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f35a0724-e81e-4e5d-ae66-607fc29025a9")) {                    Plotly.newPlot(                        "f35a0724-e81e-4e5d-ae66-607fc29025a9",                        [{"alignmentgroup": "True", "hovertemplate": "time=%{y}<br>Hold value percentage=%{text}<extra></extra>", "legendgroup": "All times", "marker": {"color": "#636efa"}, "name": "All times", "offsetgroup": "All times", "orientation": "h", "showlegend": true, "text": [61.728], "textposition": "auto", "type": "bar", "x": [61.728], "xaxis": "x", "y": ["All times"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "time=%{y}<br>Hold value percentage=%{text}<extra></extra>", "legendgroup": "No war time", "marker": {"color": "#EF553B"}, "name": "No war time", "offsetgroup": "No war time", "orientation": "h", "showlegend": true, "text": [70.37], "textposition": "auto", "type": "bar", "x": [70.37], "xaxis": "x", "y": ["No war time"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "time"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8" ...

# %%
cpi_2_years_df = get_cpi(look_back_window=60)
real_estate_2_years_df = get_price_change(look_back_window=60)
df_2_years_changes = cpi_2_years_df.join(real_estate_2_years_df)
df_2_years_changes = df_2_years_changes.dropna(how='any', axis=0)
hold_value_months = len(df_2_years_changes.loc[df_2_years_changes['price_change'] > df_2_years_changes['inflation']])
hold_value_percentage = round((hold_value_months/len(df_2_years_changes)), 4)
fig = px.pie(values=[1-hold_value_percentage,hold_value_percentage],
             names=['inflation adjusted real estate price decrease', 'inflation adjusted real estate price increase'],
            title = "Inflation adjusted price increase in 5 years periods")
fig.update_layout(title_x=0.5, titlefont=dict(size=20))
fig.show()
print("I chose to look at 5 years periods, because this a reasonable time period for an investment. We can understand from this chart that in many time periods real estate was not a good hedge against inflation. Yet, this comparison does not distinguish between 0.001% real prices decrease and 10% real prices decrease. ")
# Out:
# <div>                            <div id="e6eee297-3a87-4fae-bc69-ba1eb7818c8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6eee297-3a87-4fae-bc69-ba1eb7818c8c")) {                    Plotly.newPlot(                        "e6eee297-3a87-4fae-bc69-ba1eb7818c8c",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "label=%{label}<br>value=%{value}<extra></extra>", "labels": ["inflation adjusted real estate price decrease", "inflation adjusted real estate price increase"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [0.38039999999999996, 0.6196]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "sc ...
# I chose to look at 5 years periods, because this a reasonable time period for an investment, we can understand from this chart that in many time periods real estate was not a good hedge against inflation, but this coparison does not distinguish between 0.001% real prices decrease and 10% real prices decrease.

# %%
df['inflation_adjusted_real_estate_price_increase'] = df['price_change'] - df['inflation']
fig = px.box(df, y="inflation_adjusted_real_estate_price_increase",
             points="all")
fig.update_layout(yaxis=dict(tickfont=dict(size=15),
                             tickvals=[x * 2.5 for x in range(-4, 9)],
                             ticktext=[str(round(x * 2.5, 1)) + '%' for x in range(-4, 9)],
                             titlefont=dict(size=15)))
fig.update_layout(title_text="Inflation adjusted real estate price increase", title_x=0.5, titlefont=dict(size=30),
                  yaxis_title='')
fig.show()
# Out:
# <div>                            <div id="707c3082-7e9d-4c4f-8f4c-e558152ec3ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("707c3082-7e9d-4c4f-8f4c-e558152ec3ef")) {                    Plotly.newPlot(                        "707c3082-7e9d-4c4f-8f4c-e558152ec3ef",                        [{"alignmentgroup": "True", "boxpoints": "all", "hovertemplate": "inflation_adjusted_real_estate_price_increase=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type":